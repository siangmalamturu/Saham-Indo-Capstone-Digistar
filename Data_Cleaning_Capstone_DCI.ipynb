# %%
# ==========================================
# 1. IMPORT LIBRARIES
# ==========================================
import pandas as pd
import json
import os
import re
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from openai import OpenAI, APIConnectionError
from dotenv import load_dotenv

load_dotenv()
MY_API_KEY = os.getenv("OPEN_API_KEY")

MY_MODEL_ID = os.getenv("FINE_TUNED_MODEL")

# %%
# ==========================================
# 2. DEFINISI STOPWORDS & FUNGSI CLEANING
# ==========================================
STOPWORDS_ID = {
    'yang', 'dan', 'di', 'ke', 'dari', 'ini', 'itu', 'untuk', 'pada', 'dengan',
    'adalah', 'saya', 'kamu', 'dia', 'mereka', 'kita', 'akan', 'bisa', 'ada',
    'tidak', 'yg', 'ya', 'aja', 'gak', 'nya', 'kalo', 'kalau', 'udah', 'sudah',
    'bukan', 'tapi', 'tuh', 'dong', 'kok', 'sih', 'gue', 'lu', 'aku', 'apa',
    'bgt', 'banget', 'juga', 'lagi', 'mau', 'sama', 'banyak', 'bikin', 'buat',
    'jadi', 'terus', 'karena', 'seperti', 'atau', 'saat', 'dalam', 'masih',
    'begitu', 'semua', 'bbrp', 'utk', 'sdh', 'dgn', 'dr',
    'lebih', 'kemarin', 'per', 'punya', 'setelah', 'menjadi',
    'secara', 'lalu', 'memang', 'paling','nih','dulu','hingga','sampai','sekarang',
    'apakah','memiliki','kembali','sejak','kinerja','kira','coba','nder'
}

STOPWORDS_SAHAM = {
    'saham', 'harga', 'market', 'indeks', 'lot', 'hari', 'tahun',
    'beli', 'jual', 'hold', 'masuk', 'keluar', 'rekomendasi',
    'bbca', 'bbri', 'bmri', 'bbtn', 'tlkm', 'unvr', 'goto', 'bank', 'bca',
    'bbni', 'hmsp', 'tpia', 'bren', 'byan', 'indf', 'antm', 'asii','amp',
    'bri', 'mandiri', 'brpt', 'chandra', 'asri', 'tuck', 'wong','astra','ggrm',
    'ihsg', 'persero', 'tbk', 'lembar', 'pemegang', 'pbv', 'pukul', 'wib','pt',
    'syariah', 'low kwong','prajogo pangestu','indonesia','prajogo','pangestu','bayan','low',
    'kwong','adro','bisnis','emiten','rokok','unilever','rdtx','sampoerna','produk'
}

ALL_STOPWORDS = STOPWORDS_ID.union(STOPWORDS_SAHAM)

def load_and_clean_data(file_path):
    """Memuat dan membersihkan dataset."""
    print(f"Loading data from: {file_path}")
    if not os.path.exists(file_path):
        if os.path.exists(os.path.basename(file_path)):
            file_path = os.path.basename(file_path)
        else:
            raise FileNotFoundError("File tidak ditemukan.")

    df = pd.read_csv(file_path)

    # Hapus kolom tidak terpakai
    unused_cols = ['Quote Count', 'Reply Count', 'Retweet Count', 'Favorite Count', 'English Translation', 'Tweet Date']
    df = df.drop(columns=[c for c in unused_cols if c in df.columns], errors='ignore')

    # Fungsi Cleaning Text
    def clean_text(text):
        if not isinstance(text, str): return ""
        text = re.sub(r'\[URL\]|\[HASHTAG\]|\[USERNAME\]', '', text) # Hapus placeholder
        text = text.lower()
        text = re.sub(r'[^a-z\s]', ' ', text) # Hapus non-huruf
        text = re.sub(r'\s+', ' ', text).strip()

        # Stopword removal
        tokens = [t for t in text.split() if t not in ALL_STOPWORDS]
        return ' '.join(tokens)

    print("Cleaning data...")
    df['cleaned_text'] = df['Sentence'].apply(clean_text)

    # Hapus duplikat & data kosong
    df = df.drop_duplicates(subset=['cleaned_text'])
    df = df[df['cleaned_text'].str.strip() != '']

    print(f"Data siap. Total baris: {len(df)}")
    return df[['cleaned_text', 'Sentiment']]

# %%
# ==========================================
# 3. FUNGSI KONVERSI KE JSONL (FORMAT OPENAI)
# ==========================================
def create_finetune_jsonl(df, output_file):
    """
    Mengubah DataFrame menjadi format JSONL yang diminta OpenAI:
    {"messages": [{"role": "system", ...}, {"role": "user", ...}, {"role": "assistant", ...}]}
    """
    system_prompt = "Kamu adalah model analisis sentimen saham Indonesia. Jawab hanya dengan satu label: Positive, Negative, atau Neutral."

    with open(output_file, "w", encoding="utf-8") as f:
        for _, row in df.iterrows():
            record = {
                "messages": [
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": row["cleaned_text"]},
                    {"role": "assistant", "content": row["Sentiment"]}
                ]
            }
            f.write(json.dumps(record, ensure_ascii=False) + "\n")
    print(f"File JSONL berhasil dibuat: {output_file} ({len(df)} baris)")

# %%
# ==========================================
# 4. EKSEKUSI UTAMA (DATA PREPARATION)
# ==========================================

# A. LOAD DATA
FILE_PATH = 'data.csv'
df_clean = load_and_clean_data(FILE_PATH)

# B. SPLIT DATASET (80% Train, 10% Validation, 10% Test)
train_df, temp_df = train_test_split(
    df_clean,
    test_size=0.2,
    random_state=42,
    stratify=df_clean['Sentiment']
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42,
    stratify=temp_df['Sentiment']
)

print(f"\nDistribusi Data:")
print(f"Training Set   : {len(train_df)} ({len(train_df)/len(df_clean):.1%})")
print(f"Validation Set : {len(val_df)} ({len(val_df)/len(df_clean):.1%})")
print(f"Testing Set    : {len(test_df)} ({len(test_df)/len(df_clean):.1%})")

# C. SIMPAN FILE JSONL & CSV
create_finetune_jsonl(train_df, "sentiment_train.jsonl")
create_finetune_jsonl(val_df, "sentiment_val.jsonl")
test_df.to_csv("sentiment_test.csv", index=False)
# Out:
# Loading data from: data_cleaned_full.csv
# Cleaning data...
# Data siap. Total baris: 3141
#
# Distribusi Data:
# Training Set   : 2512 (80.0%)
# Validation Set : 314 (10.0%)
# Testing Set    : 315 (10.0%)
# File JSONL berhasil dibuat: sentiment_train.jsonl (2512 baris)
# File JSONL berhasil dibuat: sentiment_val.jsonl (314 baris)

# %%
# ==========================================
# 5. PROSES FINE-TUNING
# ==========================================
try:
    client = OpenAI(api_key=MY_API_KEY)

    print("\n--- 1. Memulai Upload File Training ---")
    # Upload Training File
    with open("sentiment_train.jsonl", "rb") as f:
        train_file = client.files.create(
            file=f,
            purpose="fine-tune"
        )
    print(f"[BERHASIL] Training File ID: {train_file.id}")

    print("\n--- 2. Memulai Upload File Validation ---")
    # Upload Validation File
    with open("sentiment_val.jsonl", "rb") as f:
        val_file = client.files.create(
            file=f,
            purpose="fine-tune"
        )
    print(f"[BERHASIL] Validation File ID: {val_file.id}")

    time.sleep(5)

    print("\n--- 3. Membuat Job Fine-Tuning ---")
    # Create Fine-Tuning Job
    job = client.fine_tuning.jobs.create(
        training_file=train_file.id,
        validation_file=val_file.id,
        model="gpt-4o-mini-2024-07-18",
        suffix="saham-indo-v1"
    )

    print(f"[BERHASIL] Job Created!")
    print(f"Job ID : {job.id}")
    print(f"Status : {job.status}")

    print("\n" + "="*50)
    print("PROSES BERJALAN DI SERVER OPENAI.")
    print("Cek email Anda untuk notifikasi saat training selesai.")
    print("="*50)

except Exception as e:
    print(f"\n[TERJADI ERROR]: {e}")
    print("Kemungkinan penyebab error:")
    print("1. API Key salah/tidak valid.")
    print("2. Saldo OpenAI habis (perlu top-up credit, bukan ChatGPT Plus).")
    print("3. File .jsonl belum terbuat (jalankan langkah sebelumnya).")
# Out:
# --- 1. Memulai Upload File Training ---
# [BERHASIL] Training File ID: file-AA151R5yhbw3EiiuSTjgbe
#
# --- 2. Memulai Upload File Validation ---
# [BERHASIL] Validation File ID: file-Pzv6MwRjUMkt2nBdxMwFKW
#
# --- 3. Membuat Job Fine-Tuning ---
# [BERHASIL] Job Created!
# Job ID : ftjob-HcuVpGmVDMJeLwRkKmOlXFDS
# Status : validating_files
#
# ==================================================
# PROSES BERJALAN DI SERVER OPENAI.
# Cek email Anda untuk notifikasi saat training selesai.
# ==================================================

# %%
JOB_ID = "ftjob-HcuVpGmVDMJeLwRkKmOlXFDS"
print(f"Memonitor status untuk Job ID: {JOB_ID}")

while True:
    try:
        # Cek status terbaru ke OpenAI
        job_status = client.fine_tuning.jobs.retrieve(JOB_ID)
        status = job_status.status
        print(f"Status saat ini: {status}")

        if status == 'succeeded':
            fine_tuned_model_id = job_status.fine_tuned_model
            print(f"\n[SUKSES] Nama Model Baru: {fine_tuned_model_id}")
            break
        elif status in ['failed', 'cancelled']:
            print(f"\n[BERHENTI] Job status: {status}")
            break

    except APIConnectionError:
        print("Gangguan koneksi dideteksi. Mencoba kembali dalam 60 detik...")
    except Exception as e:
        print(f"Terjadi error lain: {e}")
        break

    time.sleep(60)
# Out:
# Memonitor status untuk Job ID: ftjob-HcuVpGmVDMJeLwRkKmOlXFDS
# Status saat ini: validating_files
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: running
# Status saat ini: succeeded
#
# [SUKSES] Nama Model Baru: ft:gpt-4o-mini-2024-07-18:personal:saham-indo-v1:CxlsbcSP

# %%
job_details = client.fine_tuning.jobs.retrieve(JOB_ID )
print(job_details.hyperparameters)
# Out:
# Hyperparameters(batch_size=5, learning_rate_multiplier=1.8, n_epochs=3)

# %%
# ==========================================
# 1. KONFIGURASI
# ==========================================

# Inisialisasi Client
client = OpenAI(api_key=MY_API_KEY)

# ==========================================
# 2. PERSIAPAN DATA TEST
# ==========================================
try:
    if 'test_df' not in locals():
        print("Mencoba memuat data test dari 'sentiment_test.csv'...")
        test_df = pd.read_csv("sentiment_test.csv")
    else:
        print("Menggunakan data test yang sudah ada di memori.")

    print(f"Jumlah Data Test: {len(test_df)}")
except FileNotFoundError:
    print("[ERROR] File 'sentiment_test.csv' tidak ditemukan. Pastikan Anda sudah menjalankan tahap split data.")

# ==========================================
# 3. FUNGSI EVALUASI
# ==========================================
def run_evaluation_now(client, model_id, dataframe):
    print(f"\n--- MEMULAI EVALUASI PADA MODEL: {model_id} ---")
    y_true = []
    y_pred = []

    # Loop data
    for idx, row in dataframe.iterrows():
        try:
            # Ambil teks (prioritaskan cleaned_text, fallback ke Sentence)
            text_input = row.get("cleaned_text", row.get("Sentence"))

            # Request ke OpenAI
            resp = client.chat.completions.create(
                model=model_id,
                messages=[
                    {"role": "system", "content": "Kamu adalah model analisis sentimen saham Indonesia. Jawab hanya dengan satu label: Positive, Negative, atau Neutral."},
                    {"role": "user", "content": text_input}
                ],
                temperature=0
            )
            prediction = resp.choices[0].message.content.strip()

            # Simpan
            y_true.append(row["Sentiment"])
            y_pred.append(prediction)

            # Tampilkan progress agar tidak dikira macet
            print(f"[{idx+1}/{len(dataframe)}] Asli: {row['Sentiment']} | Prediksi: {prediction}")

        except Exception as e:
            print(f"[ERROR] Baris {idx}: {e}")
            # Jika errornya karena Model ID salah, loop akan berhenti
            if "model" in str(e) and "not found" in str(e):
                print(">>> STOP: Model ID tidak ditemukan. Periksa kembali MY_MODEL_ID Anda.")
                return

    # Tampilkan Report
    print("\n" + "="*40)
    print("HASIL AKHIR (CLASSIFICATION REPORT)")
    print("="*40)
    print(classification_report(y_true, y_pred, zero_division=0))

# ==========================================
# 4. EKSEKUSI LANGSUNG
# ==========================================
# Kita panggil fungsinya langsung tanpa IF/ELSE
if 'test_df' in locals():
    run_evaluation_now(client, MY_MODEL_ID, test_df)
else:
    print("Gagal menjalankan evaluasi karena data test tidak ditemukan.")
# Out:
# Menggunakan data test yang sudah ada di memori.
# Jumlah Data Test: 315
#
# --- MEMULAI EVALUASI PADA MODEL: ft:gpt-4o-mini-2024-07-18:personal:saham-indo-v1:CxlsbcSP ---
# [1985/315] Asli: Negative | Prediksi: Negative
# [845/315] Asli: Negative | Prediksi: Negative
# [1940/315] Asli: Positive | Prediksi: Positive
# [2314/315] Asli: Positive | Prediksi: Positive
# [553/315] Asli: Negative | Prediksi: Negative
# [2237/315] Asli: Neutral | Prediksi: Neutral
# [1002/315] Asli: Positive | Prediksi: Positive
# [949/315] Asli: Neutral | Prediksi: Positive
# [3016/315] Asli: Negative | Prediksi: Negative
# [924/315] Asli: Neutral | Prediksi: Neutral
# [3004/315] Asli: Positive | Prediksi: Positive
# [1791/315] Asli: Positive | Prediksi: Positive
# [1508/315] Asli: Positive | Prediksi: Positive
# [2505/315] Asli: Positive | Prediksi: Positive
# [145/315] Asli: Positive | Prediksi: Positive
# [2171/315] Asli: Positive | Prediksi: Positive
# [41/315] Asli: Negative | Prediksi: Negative
# [2220/315] Asli: Positive | Prediksi: Positive
# [2137/315] Asli: Positive | Prediksi: Negative
# [1635/315] Asli: Neutral | Prediksi: Neutral
# [2780/315] Asli: Positive | Prediksi: Positive
# [2559/315] Asli: Positive | Prediksi: Positive
# [3241/315] Asli: Positive | Prediksi: Positive
# [2431/315] Asli: Positive | Prediksi: Positive
# [960/315] Asli: Positive | Prediksi: Neutral
# [1089/315] Asli: Neutral | Prediksi: Neutral
# [1120/315] Asli: Positive | Prediksi: Positive
# [3/315] Asli: Positive | Prediksi: Positive
# [2384/315] Asli: Negative | Prediksi: Negative
# [21/315] Asli: Neutral | Prediksi: Neutral
# [3098/315] Asli: Positive | Prediksi: Positive
# [3211/315] Asli: Neutral | Prediksi: Positive
# [818/315] Asli: Positive | Prediksi: Positive
# [2965/315] Asli: Positive | Prediksi: Positive
# [878/315] Asli: Positive | Prediksi: Positive
# [1212/315] Asli: Positive | Prediksi: Positive
# [1737/315] Asli: Negative | Prediksi: Negative
# [1259/315] Asli: Positive | Prediksi: Negative
# [291/315] Asli: Positive | Prediksi: Neutral
# [3007/315] Asli: Positive | Prediksi: Neutral
# [3009/315] Asli: Positive | Prediksi: Positive
# [16/315] Asli: Positive | Prediksi: Positive
# [1462/315] Asli: Neutral | Prediksi: Neutral
# [838/315] Asli: Neutral | Prediksi: Neutral
# [1675/315] Asli: Positive | Prediksi: Positive
# [539/315] Asli: Negative | Prediksi: Negative
# [1885/315] Asli: Negative | Prediksi: Negative
# [2020/315] Asli: Neutral | Prediksi: Negative
# [1919/315] Asli: Positive | Prediksi: Positive
# [1972/315] Asli: Positive | Prediksi: Positive
# [2003/315] Asli: Positive | Prediksi: Positive
# [1825/315] Asli: Positive | Prediksi: Positive
# [409/315] Asli: Negative | Prediksi: Negative
# [541/315] Asli: Negative | Prediksi: Negative
# [3079/315] Asli: Negative | Prediksi: Negative
# [2244/315] Asli: Positive | Prediksi: Positive
# [74/315] Asli: Positive | Prediksi: Positive
# [2214/315] Asli: Positive | Prediksi: Positive
# [2718/315] Asli: Positive | Prediksi: Positive
# [3059/315] Asli: Negative | Prediksi: Negative
# [3157/315] Asli: Neutral | Prediksi: Neutral
# [1313/315] Asli: Neutral | Prediksi: Neutral
# [786/315] Asli: Negative | Prediksi: Negative
# [2141/315] Asli: Positive | Prediksi: Positive
# [2902/315] Asli: Neutral | Prediksi: Neutral
# [1119/315] Asli: Negative | Prediksi: Negative
# [1018/315] Asli: Positive | Prediksi: Positive
# [1558/315] Asli: Positive | Prediksi: Positive
# [349/315] Asli: Negative | Prediksi: Negative
# [1330/315] Asli: Negative | Prediksi: Negative
# [3284/315] Asli: Negative | Prediksi: Negative
# [146/315] Asli: Neutral | Prediksi: Neutral
# [2936/315] Asli: Neutral | Prediksi: Neutral
# [160/315] Asli: Positive | Prediksi: Positive
# [229/315] Asli: Positive | Prediksi: Positive
# [1809/315] Asli: Positive | Prediksi: Positive
# [1583/315] Asli: Positive | Prediksi: Positive
# [1608/315] Asli: Negative | Prediksi: Negative
# [546/315] Asli: Negative | Prediksi: Negative
# [1112/315] Asli: Positive | Prediksi: Positive
# [1668/315] Asli: Negative | Prediksi: Negative
# [162/315] Asli: Positive | Prediksi: Positive
# [708/315] Asli: Negative | Prediksi: Negative
# [2851/315] Asli: Neutral | Prediksi: Negative
# [1133/315] Asli: Positive | Prediksi: Positive
# [3097/315] Asli: Negative | Prediksi: Negative
# [98/315] Asli: Negative | Prediksi: Positive
# [1743/315] Asli: Positive | Prediksi: Positive
# [1764/315] Asli: Neutral | Prediksi: Neutral
# [1598/315] Asli: Negative | Prediksi: Negative
# [473/315] Asli: Neutral | Prediksi: Positive
# [2945/315] Asli: Neutral | Prediksi: Neutral
# [3043/315] Asli: Positive | Prediksi: Neutral
# [663/315] Asli: Positive | Prediksi: Positive
# [131/315] Asli: Neutral | Prediksi: Neutral
# [1876/315] Asli: Neutral | Prediksi: Neutral
# [1690/315] Asli: Negative | Prediksi: Negative
# [329/315] Asli: Neutral | Prediksi: Positive
# [1946/315] Asli: Positive | Prediksi: Positive
# [1107/315] Asli: Positive | Prediksi: Positive
# [2680/315] Asli: Positive | Prediksi: Neutral
# [2550/315] Asli: Positive | Prediksi: Positive
# [1679/315] Asli: Positive | Prediksi: Positive
# [1969/315] Asli: Neutral | Prediksi: Neutral
# [3047/315] Asli: Neutral | Prediksi: Neutral
# [1050/315] Asli: Neutral | Prediksi: Neutral
# [512/315] Asli: Neutral | Prediksi: Neutral
# [2993/315] Asli: Negative | Prediksi: Neutral
# [248/315] Asli: Positive | Prediksi: Positive
# [380/315] Asli: Negative | Prediksi: Negative
# [2421/315] Asli: Positive | Prediksi: Positive
# [832/315] Asli: Positive | Prediksi: Positive
# [1851/315] Asli: Positive | Prediksi: Positive
# [655/315] Asli: Negative | Prediksi: Negative
# [382/315] Asli: Positive | Prediksi: Positive
# [1447/315] Asli: Neutral | Prediksi: Neutral
# [1921/315] Asli: Negative | Prediksi: Neutral
# [1986/315] Asli: Negative | Prediksi: Negative
# [507/315] Asli: Negative | Prediksi: Negative
# [2673/315] Asli: Positive | Prediksi: Positive
# [394/315] Asli: Negative | Prediksi: Negative
# [286/315] Asli: Negative | Prediksi: Negative
# [33/315] Asli: Positive | Prediksi: Positive
# [327/315] Asli: Positive | Prediksi: Positive
# [195/315] Asli: Neutral | Prediksi: Positive
# [2075/315] Asli: Negative | Prediksi: Neutral
# [632/315] Asli: Positive | Prediksi: Neutral
# [1997/315] Asli: Neutral | Prediksi: Neutral
# [1699/315] Asli: Negative | Prediksi: Negative
# [1150/315] Asli: Neutral | Prediksi: Neutral
# [3202/315] Asli: Positive | Prediksi: Positive
# [1909/315] Asli: Positive | Prediksi: Positive
# [3024/315] Asli: Negative | Prediksi: Negative
# [936/315] Asli: Positive | Prediksi: Neutral
# [795/315] Asli: Negative | Prediksi: Negative
# [2932/315] Asli: Neutral | Prediksi: Neutral
# [2269/315] Asli: Positive | Prediksi: Positive
# [3137/315] Asli: Neutral | Prediksi: Neutral
# [3269/315] Asli: Neutral | Prediksi: Neutral
# [2903/315] Asli: Positive | Prediksi: Positive
# [25/315] Asli: Positive | Prediksi: Positive
# [3175/315] Asli: Positive | Prediksi: Positive
# [1284/315] Asli: Negative | Prediksi: Negative
# [1494/315] Asli: Positive | Prediksi: Positive
# [2120/315] Asli: Positive | Prediksi: Positive
# [1693/315] Asli: Negative | Prediksi: Negative
# [1390/315] Asli: Neutral | Prediksi: Negative
# [2062/315] Asli: Positive | Prediksi: Negative
# [180/315] Asli: Positive | Prediksi: Positive
# [292/315] Asli: Positive | Prediksi: Positive
# [2615/315] Asli: Positive | Prediksi: Positive
# [2755/315] Asli: Positive | Prediksi: Positive
# [2953/315] Asli: Positive | Prediksi: Positive
# [711/315] Asli: Negative | Prediksi: Negative
# [650/315] Asli: Negative | Prediksi: Negative
# [1127/315] Asli: Negative | Prediksi: Neutral
# [3270/315] Asli: Negative | Prediksi: Negative
# [889/315] Asli: Positive | Prediksi: Positive
# [1676/315] Asli: Neutral | Prediksi: Neutral
# [1364/315] Asli: Negative | Prediksi: Negative
# [1214/315] Asli: Neutral | Prediksi: Positive
# [1762/315] Asli: Neutral | Prediksi: Neutral
# [1424/315] Asli: Neutral | Prediksi: Neutral
# [2776/315] Asli: Negative | Prediksi: Negative
# [315/315] Asli: Negative | Prediksi: Positive
# [1276/315] Asli: Neutral | Prediksi: Positive
# [2966/315] Asli: Neutral | Prediksi: Neutral
# [1109/315] Asli: Positive | Prediksi: Positive
# [7/315] Asli: Neutral | Prediksi: Neutral
# [892/315] Asli: Positive | Prediksi: Positive
# [1451/315] Asli: Positive | Prediksi: Positive
# [2549/315] Asli: Positive | Prediksi: Positive
# [1957/315] Asli: Positive | Prediksi: Positive
# [2389/315] Asli: Positive | Prediksi: Positive
# [2611/315] Asli: Positive | Prediksi: Positive
# [3010/315] Asli: Neutral | Prediksi: Neutral
# [785/315] Asli: Negative | Prediksi: Neutral
# [762/315] Asli: Positive | Prediksi: Positive
# [1077/315] Asli: Positive | Prediksi: Neutral
# [2024/315] Asli: Positive | Prediksi: Negative
# [2593/315] Asli: Positive | Prediksi: Positive
# [2197/315] Asli: Positive | Prediksi: Positive
# [2656/315] Asli: Positive | Prediksi: Positive
# [2402/315] Asli: Positive | Prediksi: Positive
# [791/315] Asli: Negative | Prediksi: Negative
# [23/315] Asli: Neutral | Prediksi: Neutral
# [2729/315] Asli: Positive | Prediksi: Positive
# [1300/315] Asli: Negative | Prediksi: Negative
# [2034/315] Asli: Negative | Prediksi: Positive
# [3126/315] Asli: Negative | Prediksi: Negative
# [618/315] Asli: Negative | Prediksi: Negative
# [3062/315] Asli: Positive | Prediksi: Neutral
# [3011/315] Asli: Neutral | Prediksi: Positive
# [1603/315] Asli: Positive | Prediksi: Negative
# [253/315] Asli: Positive | Prediksi: Positive
# [2262/315] Asli: Positive | Prediksi: Positive
# [1499/315] Asli: Positive | Prediksi: Positive
# [2468/315] Asli: Positive | Prediksi: Positive
# [1623/315] Asli: Negative | Prediksi: Positive
# [3255/315] Asli: Positive | Prediksi: Negative
# [296/315] Asli: Positive | Prediksi: Positive
# [2644/315] Asli: Positive | Prediksi: Positive
# [10/315] Asli: Neutral | Prediksi: Neutral
# [2519/315] Asli: Positive | Prediksi: Neutral
# [810/315] Asli: Positive | Prediksi: Positive
# [1243/315] Asli: Positive | Prediksi: Positive
# [2814/315] Asli: Positive | Prediksi: Positive
# [1749/315] Asli: Neutral | Prediksi: Neutral
# [1776/315] Asli: Positive | Prediksi: Neutral
# [1989/315] Asli: Positive | Prediksi: Positive
# [951/315] Asli: Neutral | Prediksi: Neutral
# [1448/315] Asli: Positive | Prediksi: Positive
# [2645/315] Asli: Positive | Prediksi: Positive
# [2928/315] Asli: Positive | Prediksi: Negative
# [1523/315] Asli: Negative | Prediksi: Negative
# [3000/315] Asli: Neutral | Prediksi: Neutral
# [2634/315] Asli: Positive | Prediksi: Negative
# [2674/315] Asli: Positive | Prediksi: Positive
# [609/315] Asli: Negative | Prediksi: Negative
# [2516/315] Asli: Neutral | Prediksi: Neutral
# [699/315] Asli: Positive | Prediksi: Positive
# [2359/315] Asli: Positive | Prediksi: Positive
# [2527/315] Asli: Positive | Prediksi: Positive
# [2687/315] Asli: Positive | Prediksi: Positive
# [1195/315] Asli: Neutral | Prediksi: Negative
# [2366/315] Asli: Positive | Prediksi: Positive
# [2033/315] Asli: Positive | Prediksi: Positive
# [721/315] Asli: Positive | Prediksi: Positive
# [2194/315] Asli: Positive | Prediksi: Positive
# [869/315] Asli: Positive | Prediksi: Positive
# [973/315] Asli: Positive | Prediksi: Positive
# [1236/315] Asli: Positive | Prediksi: Positive
# [1671/315] Asli: Negative | Prediksi: Negative
# [1051/315] Asli: Positive | Prediksi: Neutral
# [2552/315] Asli: Neutral | Prediksi: Neutral
# [447/315] Asli: Negative | Prediksi: Positive
# [3155/315] Asli: Positive | Prediksi: Neutral
# [2587/315] Asli: Positive | Prediksi: Positive
# [2415/315] Asli: Positive | Prediksi: Positive
# [2802/315] Asli: Positive | Prediksi: Positive
# [3147/315] Asli: Neutral | Prediksi: Neutral
# [1566/315] Asli: Negative | Prediksi: Negative
# [1880/315] Asli: Neutral | Prediksi: Neutral
# [1977/315] Asli: Positive | Prediksi: Positive
# [1478/315] Asli: Positive | Prediksi: Positive
# [3194/315] Asli: Negative | Prediksi: Negative
# [2654/315] Asli: Positive | Prediksi: Positive
# [18/315] Asli: Positive | Prediksi: Positive
# [1444/315] Asli: Positive | Prediksi: Positive
# [1625/315] Asli: Negative | Prediksi: Negative
# [58/315] Asli: Positive | Prediksi: Neutral
# [2849/315] Asli: Positive | Prediksi: Positive
# [261/315] Asli: Positive | Prediksi: Positive
# [1101/315] Asli: Positive | Prediksi: Positive
# [2164/315] Asli: Positive | Prediksi: Positive
# [1167/315] Asli: Neutral | Prediksi: Neutral
# [5/315] Asli: Positive | Prediksi: Positive
# [2230/315] Asli: Neutral | Prediksi: Neutral
# [1726/315] Asli: Negative | Prediksi: Negative
# [735/315] Asli: Negative | Prediksi: Negative
# [1865/315] Asli: Neutral | Prediksi: Neutral
# [3129/315] Asli: Positive | Prediksi: Negative
# [1160/315] Asli: Negative | Prediksi: Negative
# [124/315] Asli: Neutral | Prediksi: Neutral
# [3012/315] Asli: Positive | Prediksi: Positive
# [3015/315] Asli: Negative | Prediksi: Negative
# [693/315] Asli: Positive | Prediksi: Positive
# [70/315] Asli: Neutral | Prediksi: Neutral
# [100/315] Asli: Neutral | Prediksi: Positive
# [2981/315] Asli: Negative | Prediksi: Neutral
# [458/315] Asli: Negative | Prediksi: Positive
# [285/315] Asli: Negative | Prediksi: Negative
# [196/315] Asli: Positive | Prediksi: Positive
# [1968/315] Asli: Positive | Prediksi: Positive
# [627/315] Asli: Positive | Prediksi: Positive
# [323/315] Asli: Positive | Prediksi: Negative
# [2423/315] Asli: Positive | Prediksi: Positive
# [1599/315] Asli: Negative | Prediksi: Positive
# [3275/315] Asli: Positive | Prediksi: Neutral
# [1705/315] Asli: Negative | Prediksi: Negative
# [704/315] Asli: Negative | Prediksi: Negative
# [2458/315] Asli: Neutral | Prediksi: Neutral
# [86/315] Asli: Positive | Prediksi: Positive
# [2005/315] Asli: Negative | Prediksi: Positive
# [381/315] Asli: Neutral | Prediksi: Neutral
# [1275/315] Asli: Neutral | Prediksi: Neutral
# [2831/315] Asli: Positive | Prediksi: Positive
# [1009/315] Asli: Positive | Prediksi: Neutral
# [13/315] Asli: Positive | Prediksi: Positive
# [1292/315] Asli: Neutral | Prediksi: Neutral
# [938/315] Asli: Neutral | Prediksi: Neutral
# [186/315] Asli: Neutral | Prediksi: Neutral
# [2108/315] Asli: Positive | Prediksi: Positive
# [419/315] Asli: Negative | Prediksi: Negative
# [2624/315] Asli: Positive | Prediksi: Positive
# [741/315] Asli: Neutral | Prediksi: Neutral
# [3065/315] Asli: Positive | Prediksi: Positive
# [1619/315] Asli: Negative | Prediksi: Positive
# [1741/315] Asli: Positive | Prediksi: Neutral
# [317/315] Asli: Positive | Prediksi: Positive
# [130/315] Asli: Positive | Prediksi: Positive
# [2264/315] Asli: Neutral | Prediksi: Neutral
# [981/315] Asli: Positive | Prediksi: Positive
# [2797/315] Asli: Negative | Prediksi: Negative
# [1011/315] Asli: Neutral | Prediksi: Neutral
# [1856/315] Asli: Neutral | Prediksi: Neutral
# [1652/315] Asli: Negative | Prediksi: Negative
# [1190/315] Asli: Negative | Prediksi: Negative
# [738/315] Asli: Neutral | Prediksi: Positive
# [3067/315] Asli: Neutral | Prediksi: Neutral
# [3231/315] Asli: Negative | Prediksi: Negative
# [1251/315] Asli: Positive | Prediksi: Neutral
# [2341/315] Asli: Positive | Prediksi: Positive
# [3271/315] Asli: Positive | Prediksi: Neutral
# [2666/315] Asli: Neutral | Prediksi: Neutral
#
# ========================================
# HASIL AKHIR (CLASSIFICATION REPORT)
# ========================================
#               precision    recall  f1-score   support
#
#     Negative       0.82      0.81      0.81        78
#      Neutral       0.70      0.81      0.75        72
#     Positive       0.88      0.82      0.85       165
#
#     accuracy                           0.82       315
#    macro avg       0.80      0.81      0.80       315
# weighted avg       0.82      0.82      0.82       315
